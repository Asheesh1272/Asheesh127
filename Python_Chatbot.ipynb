# %% [markdown]
# <a href="https://colab.research.google.com/github/Asheesh1272/Asheesh127/blob/main/Python_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

# Load a pre-trained text generation model
chatbot = pipeline("text-generation")

# User interaction loop
while True:
    user_input = input("You: ")
    if user_input.lower() == "quit":
        break

    # Generate a response from the AI
    response = chatbot(user_input)

    # Print the AI's response
    print("AI:", response[0]['generated_text'])
